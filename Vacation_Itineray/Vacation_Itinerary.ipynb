# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID           City Country  Max Temp Current Description      Lat  \
# 0        6     Butaritari      KI     81.23     overcast clouds   3.0707
# 1        7        Rikitea      PF     76.64           clear sky -23.1203
# 2        8  San Policarpo      PH     84.76    scattered clouds  12.1791
# 3       14           Tezu      IN     71.28          light rain  27.9167
# 4       19   Saint-Pierre      RE     79.92       broken clouds -21.3393
#
#         Lng          Hotel Name
# 0  172.7902  Isles Sunset Lodge
# 1 -134.9692     People ThankYou
# 2  125.5072   Agapita M. Nicart
# 3   96.1667       Circuit House
# 4   55.4781         Alize Plage

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]



# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure nothing displays. 
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Grab the first hotel from the results and store the name.
AU_vacation_df = vacation_df[ (vacation_df["Country"]== "AU")]
AU_vacation_df.dropna()
# Out:
#      City_ID             City Country  Max Temp Current Description      Lat  \
# 31        99   Port Macquarie      AU     72.90     overcast clouds -31.4333
# 70       184        Roebourne      AU     80.15          light rain -20.7833
# 82       212          Yeppoon      AU     76.78       broken clouds -23.1333
# 93       245    Alice Springs      AU     81.95           clear sky -23.7000
# 107      280         Flinders      AU     74.05     overcast clouds -34.5833
# 112      289     Port Augusta      AU     74.05    scattered clouds -32.5000
# 126      320           Mackay      AU     76.19           clear sky -21.1500
# 139      349       Nelson Bay      AU     70.11     overcast clouds -32.7167
# 154      380       Maningrida      AU     85.86          few clouds -12.0667
# 159      389           Yulara      AU     84.76    scattered clouds -25.2406
# 170      423        Katherine      AU     91.72       broken clouds -14.4667
# ...

# %%
#5a #From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# Let's pick by Minimum Temp to Maximum Temp cities. 
start = input("What is your Starting City_ID from AU List you would like for your trip? ")
stop1 = input("What is your First Stop City_ID from AU List you would like for your trip? ")
stop2 = input("What is your Second Stop City_ID from AU List you would like for your trip? ")
stop3 = input("What is your Thirth Stop City_ID from AU List you would like for your trip? ")
end = input("What is your Last City_ID from AU List you would like for your trip? ")
# Out:
# What is your Starting City_ID from AU List you would like for your trip? Mount Isa
# What is your First Stop City_ID from AU List you would like for your trip? Mareeba
# What is your Second Stop City_ID from AU List you would like for your trip? Charters Towers
# What is your Thirth Stop City_ID from AU List you would like for your trip? Mackay
# What is your Last City_ID from AU List you would like for your trip? Mount Isa

# %%
(stop1),(stop2),(stop3),(end),
# Out:
# ('Mareeba', 'Charters Towers', 'Mackay', 'Mount Isa')

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5b Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 

vacation_start =AU_vacation_df.loc[(Asia_vacation_df["City"] == stop1)]
vacation_stop1 = AU_vacation_df.loc[(Asia_vacation_df["City"] == stop2)]
vacation_stop2 = AU_vacation_df.loc[(Asia_vacation_df["City"] == stop3)] 
vacation_stop3 = AU_vacation_df.loc[(Asia_vacation_df["City"] == end)] 
vacation_end = AU_vacation_df.loc[(Asia_vacation_df["City"] == stop1)]

# %%
(vacation_start)
# Out:
#      City_ID     City Country  Max Temp Current Description   Lat       Lng  \
# 192      480  Mareeba      AU     82.44           clear sky -17.0  145.4333
#
#                       Hotel Name
# 192  Trinity Plains Tourist Park

# %%
(vacation_stop1)
# Out:
#      City_ID             City Country  Max Temp Current Description   Lat  \
# 190      473  Charters Towers      AU     78.78       broken clouds -20.1
#
#           Lng                  Hotel Name
# 190  146.2667  Cattleman's Rest Motor Inn

# %%
(vacation_stop2)
# Out:
#      City_ID    City Country  Max Temp Current Description    Lat    Lng  \
# 126      320  Mackay      AU     76.19           clear sky -21.15  149.2
#
#                     Hotel Name
# 126  International Lodge Motel

# %%
vacation_stop3
# Out:
#      City_ID       City Country  Max Temp Current Description      Lat    Lng  \
# 179      447  Mount Isa      AU     78.57           clear sky -20.7333  139.5
#
#                     Hotel Name
# 179  ibis Styles Mt Isa Verona

# %%
vacation_end
# Out:
#      City_ID     City Country  Max Temp Current Description   Lat       Lng  \
# 192      480  Mareeba      AU     82.44           clear sky -17.0  145.4333
#
#                       Hotel Name
# 192  Trinity Plains Tourist Park

# %%
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0], 
end
# Out:
# (-17.0, 145.4333)

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# Let's pick by Minimum Temp to Maximum Temp cities. 

start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0], 
start
# type(start)
# Out:
# (-17.0, 145.4333)

# %%
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0], 
end
# Out:
# (-17.0, 145.4333)

# %%
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0], 
stop1
# Out:
# (-20.1, 146.2667)

# %%
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0], 
stop2
# Out:
# (-21.15, 149.2)

# %%
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0], 
stop3
# Out:
# (-20.7333, 139.5)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
vacation_layer = gmaps.directions_layer(start, end, waypoints =[stop1, stop2, stop3],travel_mode = "DRIVING")
fig.add_layer(vacation_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
AU_vacation_df = pd.concat([AU_vacation_df],ignore_index=True)
AU_vacation_df
# Out:
#     City_ID             City Country  Max Temp Current Description      Lat  \
# 0        99   Port Macquarie      AU     72.90     overcast clouds -31.4333
# 1       184        Roebourne      AU     80.15          light rain -20.7833
# 2       212          Yeppoon      AU     76.78       broken clouds -23.1333
# 3       245    Alice Springs      AU     81.95           clear sky -23.7000
# 4       280         Flinders      AU     74.05     overcast clouds -34.5833
# 5       289     Port Augusta      AU     74.05    scattered clouds -32.5000
# 6       320           Mackay      AU     76.19           clear sky -21.1500
# 7       349       Nelson Bay      AU     70.11     overcast clouds -32.7167
# 8       380       Maningrida      AU     85.86          few clouds -12.0667
# 9       389           Yulara      AU     84.76    scattered clouds -25.2406
# 10      423        Katherine      AU     91.72       broken clouds -14.4667
# ...

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
marker_info = [info_box_template.format(**row) for index, row in AU_vacation_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = AU_vacation_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.



city_mark = AU_vacation_df["City"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=marker_info)

fig.add_layer(marker_layer)

# %%
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
